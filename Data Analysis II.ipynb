# %%
pd.set_option('display.max_rows', 500)

# %%
import pandas as pd
import numpy as np
# for Box-Cox Transformation
from scipy import stats

# for min_max scaling
from mlxtend.preprocessing import minmax_scaling

# plotting modules
import seaborn as sns

import matplotlib.pyplot as plt




np.random.seed(0) 

df = pd.read_csv('balance.txt', delim_whitespace=True)
df.head()
# Out:
#             Balance   Income Limit  Rating  Cards   Age  Education  Gender  \
# 0  12.2407984760474   14.891  3606   283.0    2.0   NaN       11.0    Male
# 1  23.2833339223376      NaN  6645   483.0    3.0  82.0       15.0  Female
# 2  22.5304088790893  104.593  7075     NaN    4.0  71.0       11.0    Male
# 3   27.652810710665  148.924  9504   681.0    3.0  36.0       11.0     NaN
# 4  16.8939784904888   55.882  4897   357.0    2.0  68.0       16.0    Male
#
#   Student Married  Ethnicity
# 0      No     Yes  Caucasian
# 1     NaN     Yes      Asian
# 2      No      No      Asian
# 3      No      No      Asian
# 4      No     Yes  Caucasian

# %% [markdown]
# ## Data Analysis II
#
# Welcome to the Data Analysis II task. In this task we are going to work on how to handle missing data as well as Data Scaling and Normalisation. Data can have missing values for a number of reasons such as observations that were not collected or data corruption. We will discuss some general considerations for missing data, discuss how Pandas chooses to represent it, and demonstrate some built-in Pandas tools for handling missing data in Python.
# ## Working with missing data
# ### Take a first look at the data
# This should always be the first step during any analysis. Depending on data sources, missing data are identified differently. Pandas identifies missing values as NaN. However, unless the data has been pre-processed to a degree that an analyst will encounter missing values as NaN. Missing values can appear as a question mark (?) or a zero (0) or minus one (-1) or a blank. So it is important to view and understand your data before anything else.
#
# We are going to use the Dataset 'balance.txt'. From the first five observations, we can see there are several missing values. They have been represented as NaN.

# %% [markdown]
# How many NaN values can you point out?
#
# Now that we have seen that there are missing values, we need to get a sense of how many missing values exist in the whole data set. We are going to find how many values we have in each column.

# %%
# get the number of missing data points per column
missing_values_count = df.isnull().sum()

# look at the # of missing points in the first ten columns
missing_values_count[0:10]
# Out:
# Balance       0
# Income        6
# Limit        15
# Rating       11
# Cards         1
# Age          10
# Education     6
# Gender        8
# Student       7
# Married       3
# dtype: int64

# %% [markdown]
# In order to get an even better sense. We need to see what percentage of all the values are missing. If we get a very high percentage we may not be able to use the data.

# %%
# how many total missing values do we have?
total_cells = np.product(df.shape)
total_missing = missing_values_count.sum()

# percent of data that is missing
(total_missing/total_cells) * 100
# Out:
# 1.7727272727272727

# %% [markdown]
# Seems like only 1.77% of the values are missing
#
# ### Drop missing values
#
# One option you have is to remove any rows or columns that contain missing values. This strategy is not generally recommended for datasets with important/sensitive data or datasets with a small number of observations. It's usually worth it to take the time to go through your data and really look at all the columns with missing values to really get to understanding your dataset.
#
# If you're sure you want to drop rows with missing values, pandas does have a handy function, dropna() to help you do this. Let's try it out on our data.

# %%
# Create a temporary dataset
temp_df = df

# remove all the rows that contain a missing value.

temp_df.dropna().head()
# Out:
#             Balance  Income Limit  Rating  Cards   Age  Education  Gender  \
# 4  16.8939784904888  55.882  4897   357.0    2.0  68.0       16.0    Male
# 5  22.4861776123913   80.18  8047   569.0    4.0  77.0       10.0    Male
# 6  10.5745164367595  20.996  3388   259.0    2.0  37.0       12.0  Female
# 7  14.5762043512884  71.408  7114   512.0    2.0  87.0        9.0    Male
# 8  7.93809029500252  15.125  3300   266.0    5.0  66.0       13.0  Female
#
#   Student Married         Ethnicity
# 4      No     Yes         Caucasian
# 5      No      No         Caucasian
# 6      No      No  African American
# 7      No      No             Asian
# 8      No      No         Caucasian

# %% [markdown]
# As you can observe observations 0,1,2,3 have been dropped from the dataframe because they contained Null values.
#
# The above proceedure removed observations. Now let us look int removing Columns.

# %%
# Create a temporary dataset
temp_df = df


# remove all columns with at least one missing value
columns_with_na_dropped = temp_df.dropna(axis=1)
columns_with_na_dropped.head()
# Out:
#             Balance
# 0  12.2407984760474
# 1  23.2833339223376
# 2  22.5304088790893
# 3   27.652810710665
# 4  16.8939784904888

# %% [markdown]
# Looks like all columns had atleast one missing values excepts the Balance column. This is one of the reasons why droping data for having NaN's may not be a very good solution. We'll explore other options.

# %% [markdown]
# ### Filling in missing values automatically
#
# We can use the Panda's fillna() function to fill in missing values in a dataframe. One option we have is to specify what we want the NaN values to be replaced with. Here, we can replace all NaN with 0.

# %%
# Create a temporary dataset
temp_df = df

# replace all NA's with 0
temp_df.fillna(0).head()
# Out:
#             Balance   Income Limit  Rating  Cards   Age  Education  Gender  \
# 0  12.2407984760474   14.891  3606   283.0    2.0   0.0       11.0    Male
# 1  23.2833339223376        0  6645   483.0    3.0  82.0       15.0  Female
# 2  22.5304088790893  104.593  7075     0.0    4.0  71.0       11.0    Male
# 3   27.652810710665  148.924  9504   681.0    3.0  36.0       11.0       0
# 4  16.8939784904888   55.882  4897   357.0    2.0  68.0       16.0    Male
#
#   Student Married  Ethnicity
# 0      No     Yes  Caucasian
# 1       0     Yes      Asian
# 2      No      No      Asian
# 3      No      No      Asian
# 4      No     Yes  Caucasian

# %% [markdown]
# Another way is to replace the missing values with whatever values that come just before or just after it in the same column. This can be used in datasets where the observations are in some sorted or logical error.

# %%
# Create a temporary dataset
temp_df = df

# replace all NA's the value that comes directly after it in the same column, 
# then replace all the reamining na's with 0
temp_df.fillna(method = 'bfill', axis=0).fillna(0).head()
# Out:
#             Balance   Income Limit  Rating  Cards   Age  Education  Gender  \
# 0  12.2407984760474   14.891  3606   283.0    2.0  82.0       11.0    Male
# 1  23.2833339223376  104.593  6645   483.0    3.0  82.0       15.0  Female
# 2  22.5304088790893  104.593  7075   681.0    4.0  71.0       11.0    Male
# 3   27.652810710665  148.924  9504   681.0    3.0  36.0       11.0    Male
# 4  16.8939784904888   55.882  4897   357.0    2.0  68.0       16.0    Male
#
#   Student Married  Ethnicity
# 0      No     Yes  Caucasian
# 1      No     Yes      Asian
# 2      No      No      Asian
# 3      No      No      Asian
# 4      No     Yes  Caucasian

# %% [markdown]
# ### Other ways of handling missing data
#
# #### Mean, Median and Mode Imputation
#
# Using the measures of central tendency involves substituting the missing values with the mean or median for numerical variables and the mode for categorical variables. This imputation technique works well with when the values are missing completely at random. One disadvantage is that mean imputation reduces variance in the dataset.
#
# #### Imputation with Linear Regression
#
# This is an imputation technique that utilises variables from the observed data to replace the missing values with predicted values from a regression model. Complete observations  are used to generate the regression equation; the equation is then used to predict missing values for incomplete observations. In an iterative process, values for the missing variable are inserted and then all cases are used to predict the dependent variable. These steps are repeated until there is little difference between the predicted values from one step to the next, that is they converge.  The major drawback of using this method is that it reduces variability. Though we have not introduced regression yet, its important to keep this in mind.
#
# #### k-Neareast Neighbor (kNN) Imputation
#
# For k-Nearest Neighbor imputation, the values are obtained by using similarity-based methods that rely on distance metrics (Euclidean distance, Jaccard similarity, Minkowski norm etc). They can be used to predict both discrete and continuous attributes. KNN workes by finding other observations that are almost similar to the observation with the missing value. For example, if the observation is 'Female' and 'Asian' we will find other users similar to her and get the mean or mode of the missing value. The main disadvantage of using kNN imputation is that it becomes time-consuming when analysing large datasets because it searches for similar instances through all the dataset.
#
#
# ### Scaling and Normalisation
#
# #### Scaling vs. Normalisation: What's the difference?
# One of the reasons that it's easy to get confused between scaling and normalisation is because the terms are sometimes used interchangeably and, to make it even more confusing, they are very similar! In both cases, you're transforming the values of numeric variables so that the transformed data points have specific helpful properties. The difference is that, in scaling, you're changing the range of your data while in normalisation you're changing the shape of the distribution of your data. Let's talk a little more in-depth about each of these options.
#
#
# #### Scaling
# This means that you're transforming your data so that it fits within a specific scale, like 0-100 or 0-1. You want to scale data when you're using methods based on measures of how far apart data points, like support vector machines, or SVM or k-nearest neighbors, or KNN. With these algorithms, a change of "1" in any numeric feature is given the same importance.
#
# For example, you might be looking at the prices of some products in both Yen and US Dollars. One US Dollar is worth about 100 Yen, but if you don't scale your prices methods like SVM or KNN will consider a difference in price of 1 Yen as important as a difference of 1 US Dollar! This clearly doesn't fit with our intuitions of the world. With currency, you can convert between currencies. But what about if you're looking at something like height and weight? It's not entirely clear how many pounds should equal one inch (or how many kilograms should equal one meter).
#
# By scaling your variables, you can help compare different variables on equal footing. To help solidify what scaling looks like, let's look at a made-up example. (Don't worry, we'll work with real data in just a second, this is just to help illustrate the point.)

# %%
# generate 1000 data points randomly drawn from an exponential distribution
original_data = np.random.exponential(size = 1000)

# mix-max scale the data between 0 and 1
scaled_data = minmax_scaling(original_data, columns = [0])

# plot both together to compare
fig, ax=plt.subplots(1,2)
sns.distplot(original_data, ax=ax[0])
ax[0].set_title("Original Data")
sns.distplot(scaled_data, ax=ax[1])
ax[1].set_title("Scaled data")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Scaled data')

# %% [markdown]
# Notice that the *shape* of the data doesn't change, but that instead of ranging from 0 to 8ish, it now ranges from 0 to 1.
#
# ## Practice

# %%
# read in all our data
countries = pd.read_csv("countries.csv")

countries.head()
# Out:
#   Country                               Country Groups  BX.KLT.DINV.WD.GD.ZS  \
# 0     CEB               Central Europe and the Baltics              1.555790
# 1     CSS                       Caribbean small states              4.658176
# 2     EAP  East Asia & Pacific (excluding high income)              3.796483
# 3     EAR                   Early-demographic dividend              2.073571
# 4     EAS                          East Asia & Pacific              2.930966
#
#    EG.ELC.ACCS.ZS  EG.FEC.RNEW.ZS  EN.ATM.CO2E.PC  FP.CPI.TOTL.ZG  \
# 0      100.000000       14.538355        6.820042        1.840965
# 1       93.114511        9.096342        9.277109        3.250344
# 2       94.997330       16.471817        5.106045        3.789836
# 3       79.455104       26.481427        2.119827        4.580200
# 4       95.496185       13.729447        5.701783        3.247588
#
#    IT.CEL.SETS.P2  IT.NET.USER.ZS  NE.EXP.GNFS.ZS  ...  NY.GDP.PCAP.CD  \
# 0      122.192106       58.599297       52.333390  ...    12567.128310
# 1      113.628492       35.407690       44.935642  ...     8726.326154
# 2       69.905604       28.957482       30.572597  ...     4007.323783
# 3       68.069446       12.835425       27.711023  ...     2926.483907
# 4       73.657018       34.269800       32.153225  ...     7674.475705
#
#    SP.DYN.AMRT.FE  SP.DYN.AMRT.MA  SP.DYN.CBRT.IN  SP.DYN.CDRT.IN  \
# 0       77.039930      189.578062       10.543330       11.429917
# 1      121.928584      200.568068       17.555646        7.436407
# 2       91.717833      134.835195       14.439063        7.019396
# 3      150.595639      214.978616       22.914627        7.028941
# 4       86.702958      130.465277       13.880915        7.095146
#
#    SP.DYN.IMRT.IN  SP.DYN.LE00.IN  SP.DYN.TFRT.IN  SP.POP.GROW  \
# 0        6.019183       75.295349        1.465325    -0.362710
# 1       18.406085       72.252392        2.151960     0.642147
# 2       19.100000       73.482345        1.843869     0.713160
# 3       40.042149       67.955732        2.763140     1.534541
# 4       18.136433       74.383915        1.797065     0.675231
#
#    SP.URB.TOTL.IN.ZS
# 0          62.059417
# 1          42.083135
# 2          47.696831
# 3          42.113134
# 4          51.791229
#
# [5 rows x 21 columns]

# %%
# scale the goals from 0 to 1
scaled_data = minmax_scaling(countries['IT.CEL.SETS.P2'], columns = [0])

# plot the original & scaled data together to compare
fig, ax=plt.subplots(1,2)
sns.distplot(countries['IT.CEL.SETS.P2'], ax=ax[0])
ax[0].set_title("Original Data")
sns.distplot(scaled_data, ax=ax[1])
ax[1].set_title("Scaled data")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\mlxtend\preprocessing\scaling.py:40: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ary_new = ary_new[:, np.newaxis]
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Scaled data')

# %% [markdown]
# You can see that scaling changed the scales of the plots dramatically (but not the shape of the data: it looks like most campaigns have small goals but a few have very large ones)

# %% [markdown]
# ## Normalisation
#
# Scaling just changes the range of your data. Normalisation is a more radical transformation. The point of normalisation is to change your observations so that they can be described as a normal distribution.
#
# > **[Normal distribution:](https://en.wikipedia.org/wiki/Normal_distribution)** Also known as the "bell curve", this is a specific statistical distribution where a roughly equal observations fall above and below the mean, the mean and the median are the same, and there are more observations closer to the mean. The normal distribution is also known as the Gaussian distribution.
#
# In general, you'll only want to normalise your data if you're going to be using a machine learning or statistics technique that assumes your data is normally distributed. Some examples of these include t-tests, ANOVAs, linear regression, linear discriminant analysis (LDA) and Gaussian naive Bayes. (Pro tip: any method with "Gaussian" in the name probably assumes normality.)

# %%
# normalise the pledges (w/ Box-Cox)
positive_pledges = countries['NE.EXP.GNFS.ZS']
normalised_pledges = stats.boxcox(positive_pledges)[0]

# plot both together to compare
fig, ax=plt.subplots(1,2)
sns.distplot(positive_pledges, ax=ax[0])
ax[0].set_title("Original Data")
sns.distplot(normalised_pledges, ax=ax[1])
ax[1].set_title("Normalised data")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Normalised data')

# %% [markdown]
# ## Compulsory Tasks

# %%
# Read in Pakistan.csv and display the first 5 columns
with open('Pakistan.csv','r') as f:
    print(f)
pk = pd.read_csv('Pakistan.csv',encoding = 'cp1252')
pk.iloc[:,0:5]
# Out:
#       S#              Date                   Islamic Date Blast Day Type  \
# 0      1  November 19-1995  25 Jumaada al-THaany 1416 A.H        Holiday
# 1      2   November 6-2000           10 SHa`baan 1421 A.H    Working Day
# 2      3        May 8-2002              25 safar 1423 A.H    Working Day
# 3      4      June 14-2002     3 Raby` al-THaany 1423 A.H    Working Day
# 4      5       July 4-2003     4 Jumaada al-awal 1424 A.H    Working Day
# ..   ...               ...                            ...            ...
# 491  492   October 05-2017           13 MuHarram 1439 A.H    Working Day
# 492  493   October 19-2017           27 MuHarram 1439 A.H    Working Day
# 493  494   November 9-2017              19 Safar 1439 A.H    Working Day
# 494  495  November 24-2017       5 Rabi Al-Awwal 1439 A.H    Working Day
# 495  496  November 25-2017       6 Rabi Al-Awwal 1439 A.H    Working Day
#
#     Holiday Type
# 0        Weekend
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 491          NaN
# 492          NaN
# 493          NaN
# 494          NaN
# 495          NaN
#
# [496 rows x 5 columns]

# %%
pk.iloc[:,1].isnull().sum()
# Out:
# 0

# %%
range(len(pk.columns))
# Out:
# range(0, 26)

# %%
pk.loc[pk.index[0],['Islamic Date']]
# Out:
# Islamic Date    25 Jumaada al-THaany 1416 A.H
# Name: 0, dtype: object

# %%
# get the number of missing data points per column
missing = pd.DataFrame({'Column':[],'Number of missing datapoints':[]})
for i in range(len(pk.columns)):
    missing.loc[i,['Column']] = pk.columns[i]
    missing.loc[i,['Number of missing datapoints']] = pk.iloc[:,i].isnull().sum()

# look at the # of missing points in the first ten columns
missing = missing.sort_values(by = ['Number of missing datapoints'],ascending = False)
missing.reset_index(inplace = True, drop = True)
missing
# Out:
#                      Column  Number of missing datapoints
# 0              Holiday Type                         424.0
# 1    Explosive Weight (max)                         324.0
# 2   Influencing Event/Event                         305.0
# 3                      Time                         211.0
# 4            Hospital Names                         199.0
# 5              Islamic Date                         154.0
# 6                Killed Min                         146.0
# 7               Injured Min                         131.0
# 8     No. of Suicide Blasts                          82.0
# 9      Targeted Sect if any                          48.0
# 10     Location Sensitivity                          36.0
# 11        Location Category                          35.0
# 12        Open/Closed Space                          35.0
# 13              Injured Max                          32.0
# 14              Target Type                          26.0
# 15               Killed Max                          16.0
# 16           Blast Day Type                          10.0
# 17           Temperature(F)                           7.0
# 18           Temperature(C)                           5.0
# 19                 Location                           3.0
# 20                Longitude                           3.0
# 21                 Latitude                           3.0
# 22                     Date                           0.0
# 23                 Province                           0.0
# 24                     City                           0.0
# 25                       S#                           0.0

# %%
pk.loc[pk['Islamic Date'].isnull()]
# Out:
#       S#                Date Islamic Date Blast Day Type       Holiday Type  \
# 8      9         May 31-2004          NaN    Working Day                NaN
# 144  145    December 28-2008          NaN        Holiday            Weekend
# 311  312         May 13-2011          NaN    Working Day                NaN
# 312  313         May 14-2011          NaN    Working Day                NaN
# 313  314         May 25-2011          NaN    Working Day                NaN
# 314  315         May 26-2011          NaN    Working Day                NaN
# 315  316         May 28-2011          NaN    Working Day                NaN
# 316  317         June 5-2011          NaN        Holiday            Weekend
# 317  318        June 12-2011          NaN        Holiday            Weekend
# 318  319        June 13-2011          NaN    Working Day                NaN
# 319  320        June 25-2011          NaN    Working Day                NaN
# 320  321        July 11-2011          NaN    Working Day                NaN
# 321  322        July 21-2011          NaN    Working Day                NaN
# 322  323        July 24-2011          NaN        Holiday            Weekend
# 323  324       August 6-2011          NaN    Working Day                NaN
# 324  325      August 11-2011          NaN    Working Day                NaN
# 325  326      August 19-2011          NaN    Working Day                NaN
# 328  329    September 7-2011          NaN    Working Day                NaN
# 329  330   September 15-2011          NaN    Working Day                NaN
# 330  331   September 19-2011          NaN    Working Day                NaN
# 331  332     October 28-2011          NaN    Working Day                NaN
# 332  333     November 7-2011          NaN    Working Day                NaN
# 333  334    November 16-2011          NaN    Working Day                NaN
# 334  335    November 18-2011          NaN    Working Day                NaN
# 335  336    December 24-2011          NaN    Working Day                NaN
# 336  337      January 3-2012          NaN    Working Day                NaN
# 337  338      January 3-2012          NaN    Working Day                NaN
# 338  339      January 3-2012          NaN    Working Day                NaN
# 339  340     January 14-2012          NaN    Working Day                NaN
# 340  341     January 30-2012          NaN    Working Day                NaN
# 341  342    February 17-2012          NaN    Working Day                NaN
# 342  343    February 16-2012          NaN    Working Day                NaN
# 343  344    February 24-2012          NaN    Working Day                NaN
# 344  345        March 3-2012          NaN        Holiday            Weekend
# 345  346        March 4-2012          NaN        Holiday            Weekend
# 346  347       March 11-2012          NaN        Holiday            Weekend
# 347  348       March 15-2012          NaN    Working Day                NaN
# 348  349       March 23-2012          NaN    Working Day                NaN
# 349  350        April 5-2012          NaN    Working Day                NaN
# 350  351          May 4-2012          NaN    Working Day                NaN
# 351  352        June 12-2012          NaN    Working Day                NaN
# 352  353        June 28-2012          NaN    Working Day                NaN
# 353  354        July 16-2012          NaN    Working Day                NaN
# 354  355    September 3-2012          NaN    Working Day                NaN
# 355  356   September 10-2012          NaN    Working Day                NaN
# 356  357     October 13-2012          NaN        Holiday            Weekend
# 357  358     November 4-2012          NaN        Holiday            Weekend
# 358  359     November 7-2012          NaN    Working Day                NaN
# 359  360     November 8-2012          NaN    Working Day                NaN
# 360  361    November 19-2012          NaN    Working Day                NaN
# 361  362    November 21-2012          NaN    Working Day                NaN
# 362  363    November 21-2012          NaN    Working Day                NaN
# 363  364    November 25-2012          NaN        Holiday             Ashura
# 364  365    November 29-2012          NaN    Working Day                NaN
# 365  366     December 4-2012          NaN    Working Day                NaN
# 366  367     December 5-2012          NaN    Working Day                NaN
# 367  368    December 22-2012          NaN        Holiday            Weekend
# 368  369     January 10-2013          NaN    Working Day                NaN
# 369  370     February 1-2013          NaN    Working Day                NaN
# 370  371    February 14-2013          NaN    Working Day                NaN
# 371  372    February 14-2013          NaN    Working Day                NaN
# 372  373    February 16-2013          NaN    Working Day            Weekend
# 373  374    February 18-2013          NaN    Working Day                NaN
# 374  375       March 18-2013          NaN    Working Day                NaN
# 375  376       March 23-2013          NaN        Holiday       Pakistan Day
# 376  377       March 29-2013          NaN    Working Day                NaN
# 377  378       April 16-2013          NaN    Working Day                NaN
# 378  379       April 16-2013          NaN    Working Day                NaN
# 379  380       April 20-2013          NaN    Working Day                NaN
# 380  381       April 23-2013          NaN    Working Day                NaN
# 381  382       April 29-2013          NaN    Working Day                NaN
# 382  383          May 1-2013          NaN        Holiday         Labour Day
# 383  384          May 7-2013          NaN    Working Day                NaN
# 384  385          May 8-2013          NaN    Working Day                NaN
# 385  386         May 11-2013          NaN        Holiday  General Elections
# 386  387         May 12-2013          NaN        Holiday            Weekend
# 387  388         May 24-2013          NaN    Working Day                NaN
# 388  389         June 3-2013          NaN    Working Day                NaN
# 389  390        June 15-2013          NaN    Working Day                NaN
# 390  391        June 15-2013          NaN    Working Day                NaN
# 391  392        June 18-2013          NaN    Working Day                NaN
# 392  393        June 21-2013          NaN    Working Day                NaN
# 393  394        June 30-2013          NaN        Holiday            Weekend
# 394  395         July 8-2013          NaN    Working Day                NaN
# 395  396        July 25-2013          NaN    Working Day                NaN
# 396  397        July 26-2013          NaN    Working Day                NaN
# 397  398       August 8-2013          NaN        Holiday       Eid Holidays
# 398  399   September 22-2013          NaN        Holiday                NaN
# 399  400      October 2-2013          NaN    Working Day                NaN
# 400  401      October 3-2013          NaN    Working Day                NaN
# 401  402     October 11-2013          NaN    Working Day                NaN
# 402  403     October 16-2013          NaN        Holiday       Eid Holidays
# 403  404    November 16-2013          NaN        Holiday            Weekend
# 404  405    November 19-2013          NaN    Working Day                NaN
# 405  406    November 22-2013          NaN    Working Day                NaN
# 406  407    December 17-2013          NaN    Working Day                NaN
# 407  408    December 18-2013          NaN    Working Day                NaN
# 408  409    December 20-2013          NaN    Working Day                NaN
# 409  410      January 1-2014          NaN    Working Day                NaN
# 410  411      January 6-2014          NaN    Working Day                NaN
# 411  412      January 9-2014          NaN    Working Day                NaN
# 412  413     January 20-2014          NaN    Working Day                NaN
# 413  414     January 23-2014          NaN            NaN                NaN
# 414  415     January 29-2014          NaN    Working Day                NaN
# 415  416     February 4-2014          NaN    Working Day                NaN
# 416  417     February 7-2014          NaN    Working Day                NaN
# 417  418    February 10-2014          NaN    Working Day                NaN
# 418  419    February 13-2014          NaN    Working Day                NaN
# 419  420    February 24-2014          NaN    Working Day                NaN
# 420  421        March 3-2014          NaN    Working Day                NaN
# 421  422       March 14-2014          NaN    Working Day                NaN
# 422  423       April 24-2014          NaN    Working Day                NaN
# 423  424         May 11-2014          NaN        Holiday                NaN
# 424  425         June 4-2014          NaN    Working Day                NaN
# 425  426         June 8-2014          NaN        Holiday                NaN
# 426  427         June 9-2014          NaN    Working Day                NaN
# 427  428        June 19-2014          NaN    Working Day                NaN
# 428  429        June 24-2014          NaN    Working Day                NaN
# 429  430   September 24-2014          NaN    Working Day                NaN
# 430  431     October 04-2014          NaN    Working Day                NaN
# 431  432     October 15-2014          NaN            NaN                NaN
# 432  433     October 23-2014          NaN    Working Day                NaN
# 433  434    November 02-2014          NaN        Holiday            Weekend
# 434  435    December 16-2014          NaN            NaN                NaN
# 435  436    December 28-2014          NaN            NaN                NaN
# 436  437     January 30-2015          NaN            NaN                NaN
# 437  438    February 13-2015          NaN            NaN                NaN
# 438  439    February 17-2015          NaN            NaN                NaN
# 439  440    February 18-2015          NaN            NaN                NaN
# 440  441       March 15-2015          NaN            NaN                NaN
# 441  442       March 20-2015          NaN            NaN                NaN
# 442  443          May 6-2015          NaN    Working Day                NaN
# 443  444         May 26-2015          NaN    Working Day                NaN
# 444  445         May 26-2015          NaN    Working Day                NaN
# 445  446         May 29-2015          NaN    Working Day                NaN
# 446  447        June 06-2015          NaN        Weekend                NaN
# 447  448        June 08-2015          NaN    Working Day                NaN
# 448  449        June 11-2015          NaN    Working Day                NaN
# 449  450        June 29-2015          NaN    Working Day                NaN
# 450  451        July 17-2015          NaN        Holiday                NaN
# 451  452      August 16-2015          NaN        Holiday                NaN
# 452  453      August 27-2015          NaN    Working Day                NaN
# 453  454   September 01-2015          NaN    Working Day                NaN
# 454  455   September 20-2015          NaN        Holiday                NaN
# 455  456     October 14-2015          NaN    Working Day                NaN
# 456  457     October 22-2015          NaN        Holiday     Ashura Holiday
# 457  458     October 23-2015          NaN        Holiday     Ashura Holiday
# 458  459  December   29-2015          NaN    Working Day                NaN
# 459  460    January  13-2016          NaN    Working Day                NaN
# 460  461    January  19-2016          NaN    Working Day                NaN
# 461  462    January  29-2016          NaN    Working Day                NaN
# 462  463  February   06-2016          NaN    Working Day                NaN
# 463  464       March 07-2016          NaN    Working Day                NaN
# 464  465       March 27-2016          NaN        Holiday                NaN
#
#                       Time                 City   Latitude  Longitude  \
# 8                  evening             Karachi   24.991800    66.9911
# 144            10:30:00 AM                Buner  34.394300    72.6151
# 311                6:00 AM            Charsadda  34.150900    71.7359
# 312  11:20:00 AM/ 11:00 AM            D.G Khan   30.050000    70.6333
# 313                4:40 AM             Peshawar  34.004300    71.5448
# 314                6:00 PM                Hangu  33.535100    71.0713
# 315               10:00 AM        Bajaur Agency  34.871800    71.5249
# 316                8:45 PM            Nowshehra  34.032200    73.0944
# 317               11:45 PM             Peshawar  34.004300    71.5448
# 318                3:00 PM            Islamabad  33.718000    73.0718
# 319                    NaN            D.I Khan   31.823800    70.9095
# 320                    NaN             Peshawar  34.004300    71.5448
# 321                    NaN     South waziristan  32.320200    69.8597
# 322                    NaN     South waziristan  32.320200    69.8597
# 323                    NaN      Mohmand Agency   32.974600    70.1456
# 324                    NaN             Peshawar  34.004300    71.5448
# 325     Friday prayer time        Khyber Agency  34.021100    71.2874
# 328                    NaN               Quetta  30.209500    67.0182
# 329             After noon            Lower Dir  34.845300    71.9046
# 330                7:30 AM              karachi  24.991800    66.9911
# 331                    NaN            Nowshehra  34.032200    73.0944
# 332                    NaN               Swabi   34.133500    72.4702
# 333                    NaN              Karachi  24.991800    66.9911
# 334                 3:38AM              Karachi  24.991800    66.9911
# 335        5:30 AM/5:40 AM                Bannu  32.935000    70.6688
# 455                    NaN               Taunsa  30.712665  70.658161
# 456                    NaN               Quetta  30.182971  66.998734
# 457                    NaN            Jacobabad  28.274681  68.712889
# 458                    NaN               Mardan  34.200114  72.050801
# 459                    NaN               Quetta  30.165686   67.00178
# 460                    NaN             Peshawar  33.999533   71.42502
# 461                    NaN                 Zhob  31.341261  69.448659
# 462                    NaN               Quetta  30.199805  67.010157
# 463                    NaN  Shabqadar-Charsadda  34.149433  71.742781
# 464                    NaN               Lahore  31.512930   74.28899
#
#         Province  ... Targeted Sect if any Killed Min Killed Max Injured Min  \
# 8          Sindh  ...               Shiite       16.0       18.0         NaN
# 144          KPK  ...                 None       34.0       37.0         NaN
# 311          KPK  ...                 None       82.0       95.0       128.0
# 312          KPK  ...                 None        NaN        3.0         NaN
# 313          KPK  ...                 None        8.0       11.0        41.0
# 314          KPK  ...                 None       28.0       32.0        55.0
# 315         FATA  ...                Sunni        NaN        8.0         NaN
# 316          KPK  ...                 None       18.0       19.0        28.0
# 317          KPK  ...                 None       32.0       35.0        80.0
# 318      Capital  ...                 None        1.0        2.0         4.0
# 319          KPK  ...                 None        NaN       10.0         3.0
# 320          KPK  ...                 None        NaN        7.0        25.0
# 321         FATA  ...                  NaN        NaN        NaN         NaN
# 322         FATA  ...                  NaN        NaN        1.0         NaN
# 323         Fata  ...                  NaN        NaN        1.0         NaN
# 324          KPK  ...                  NaN        0.0        2.0         NaN
# 325          KPK  ...                  NaN       47.0       60.0        70.0
# 328  Baluchistan  ...                  NaN       26.0       28.0        60.0
# 329          KPK  ...                  NaN       26.0       34.0        63.0
# 330        Sindh  ...                  NaN        NaN        8.0         4.0
# 331          KPK  ...                  NaN        NaN        2.0         NaN
# 332          KPK  ...                  NaN        NaN        3.0         NaN
# 333        Sindh  ...                 None        5.0        7.0         NaN
# 334        Sindh  ...                 None        NaN        1.0         NaN
# 335          KPK  ...                 None        4.0        6.0        18.0
# 336       Punjab  ...                 None        NaN        2.0         NaN
# 337          KPK  ...                 None        NaN        2.0        19.0
# 338         FATA  ...                 None        NaN        3.0         7.0
# 339          KPK  ...                 None        4.0        8.0         7.0
# 340          KPK  ...                 None        3.0        4.0         7.0
# 341         FATA  ...               Shiite       21.0       28.0         NaN
# 342         FATA  ...                 None        1.0        1.0         3.0
# 343          KPK  ...                 None        0.0        4.0         NaN
# 344          KPK  ...                 None        0.0        1.0         NaN
# 345          KPK  ...                 None        NaN        0.0         NaN
# 346          KPK  ...                 None       14.0       15.0        30.0
# 347          KPK  ...                 None        1.0        1.0         2.0
# 348          KPK  ...                 None        5.0       13.0         9.0
# 349        Sindh  ...                 None        4.0        7.0        12.0
# 350         FATA  ...                 None       24.0       26.0        40.0
# 351          KPK  ...                 None        2.0        3.0         NaN
# 352  Baluchistan  ...               Shiite       13.0       14.0        20.0
# 353          KPK  ...                 None        2.0        7.0         2.0
# 354          KPK  ...                 None        0.0        2.0        18.0
# 355         FATA  ...                 None       14.0       15.0        40.0
# 356          KPK  ...                 None       13.0       20.0        39.0
# 357          KPK  ...                 None        5.0        6.0         7.0
# 358          KPK  ...                 None        6.0        8.0        28.0
# 359        Sindh  ...                 None        0.0        3.0        18.0
# 360         FATA  ...                 None        0.0        0.0         3.0
# 361        Sindh  ...               Shiite        3.0        4.0         4.0
# 362       Punjab  ...               Shiite       12.0       20.0        25.0
# 363          KPK  ...               Shiite        5.0        6.0        70.0
# 364         FATA  ...                 None        5.0        8.0        10.0
# 365          KPK  ...                 None        NaN        NaN         6.0
# 366         FATA  ...                 None        2.0        3.0        20.0
# 367          KPK  ...                 None        NaN        9.0        17.0
# 368  Baluchistan  ...               Shiite       51.0       93.0       116.0
# 369          KPK  ...                Sunni       24.0       27.0        40.0
# 370          KPK  ...                 None        7.0        NaN         8.0
# 371          KPK  ...                 None        0.0        0.0         1.0
# 372  Baluchistan  ...               Shiite       64.0       84.0       180.0
# 373          KPK  ...                 None        5.0        NaN         7.0
# 374          KPK  ...                 None        2.0        4.0        22.0
# 375         FATA  ...                 None        8.0       22.0        20.0
# 376          KPK  ...                 None        5.0       12.0        11.0
# 377          KPK  ...                 None       16.0       18.0        49.0
# 378         FATA  ...                 None        7.0        9.0         8.0
# 379         FATA  ...                 None        4.0        4.0         4.0
# 380  Baluchistan  ...               Shiite        6.0        6.0        37.0
# 381          KPK  ...                 None        8.0       10.0        30.0
# 382        Sindh  ...                 None        1.0        1.0         2.0
# 383          KPK  ...                 None       12.0       12.0        35.0
# 384          KPK  ...                 None        2.0        3.0        23.0
# 385        Sindh  ...                  NaN        2.0        2.0         3.0
# 386  Baluchistan  ...                 None        6.0        7.0        45.0
# 387          KPK  ...                 None        3.0        3.0         2.0
# 388         FATA  ...                 None        NaN        NaN         2.0
# 389  Baluchistan  ...                 None       12.0       14.0        19.0
# 390  Baluchistan  ...                 None       11.0       11.0         NaN
# 391          KPK  ...                 None       27.0       34.0        52.0
# 392          KPK  ...               Shiite       14.0       15.0        28.0
# 393  Baluchistan  ...               Shiite       28.0       30.0        65.0
# 394          KPK  ...                  NaN        6.0        8.0        10.0
# 395        Sindh  ...                 None        8.0        9.0        30.0
# 396          KPK  ...               Shiite       43.0       50.0       180.0
# 397  Baluchistan  ...                 None       30.0       38.0        50.0
# 398          KPK  ...                 None       78.0       81.0       100.0
# 399  Baluchistan  ...                 None        6.0        8.0        10.0
# 400          KPK  ...                 None       15.0       17.0        22.0
# 401         FATA  ...                 None        2.0        2.0         2.0
# 402          KPK  ...                 None        8.0        9.0        30.0
# 403          KPK  ...                 None        0.0        0.0         7.0
# 404         FATA  ...                 None        7.0        7.0         1.0
# 405          KPK  ...                 None        0.0        0.0        26.0
# 406       Punjab  ...               Shiite        3.0        3.0        14.0
# 407         FATA  ...                 None        5.0        5.0        25.0
# 408        Sindh  ...                 None        2.0        2.0        20.0
# 409  Baluchistan  ...               Shiite        2.0        3.0        30.0
# 410          KPK  ...               Shiite        2.0        2.0         2.0
# 411        Sindh  ...                 None        3.0        3.0         7.0
# 412       Punjab  ...                 None       13.0       13.0        15.0
# 413          KPK  ...                  NaN        NaN        6.0         NaN
# 414        Sindh  ...                 None        3.0        3.0         0.0
# 415          KPK  ...                 None        9.0        9.0        25.0
# 416       Punjab  ...                 None        0.0        0.0         5.0
# 417          KPK  ...                 None        4.0        4.0         3.0
# 418        Sindh  ...                 None       11.0       13.0        36.0
# 419          KPK  ...                 None        2.0        3.0         8.0
# 420      Capital  ...                 None       11.0       11.0        24.0
# 421          KPK  ...                 None        8.0       11.0        32.0
# 422        Sindh  ...                 None        2.0        4.0         2.0
# 423          KPK  ...                 None        4.0        5.0         9.0
# 424       Punjab  ...                 None        5.0        5.0         5.0
# 425  Baluchistan  ...               Shiite       23.0       30.0         7.0
# 426        Sindh  ...                  NaN        NaN       28.0         NaN
# 427          KPK  ...                 None        1.0        2.0         5.0
# 428         FATA  ...                 None        3.0        3.0         1.0
# 429          KPK  ...                 None        4.0        5.0        18.0
# 430  Baluchistan  ...               Shiite        5.0        5.0        12.0
# 431         FATA  ...                  NaN        NaN        7.0         NaN
# 432  Baluchistan  ...                 None        2.0        3.0        15.0
# 433       Punjab  ...                 None       45.0       55.0        70.0
# 434          KPK  ...                  NaN        NaN      148.0         NaN
# 435  Balochistan  ...                  NaN        NaN        2.0         NaN
# 436        Sindh  ...                  NaN       60.0       62.0         NaN
# 437          KPK  ...                  NaN        NaN       21.0         NaN
# 438       Punjab  ...                  NaN        5.0        9.0         NaN
# 439       Punjab  ...                  NaN        NaN        5.0         NaN
# 440       Punjab  ...                  NaN        NaN       17.0        70.0
# 441        Sindh  ...                  NaN        2.0        3.0         0.0
# 442         FATA  ...                  NaN        2.0        3.0         NaN
# 443        Sindh  ...                  NaN        1.0        2.0         NaN
# 444        Sindh  ...                  NaN        NaN        5.0         NaN
# 445       Punjab  ...                  NaN        1.0        2.0         NaN
# 446       Punjab  ...                  NaN        NaN        2.0         NaN
# 447         FATA  ...                  NaN        7.0       19.0         NaN
# 448          KPK  ...                  NaN        1.0        2.0         4.0
# 449       Punjab  ...                  NaN        1.0        4.0         NaN
# 450  Balochistan  ...                  NaN        1.0        1.0         NaN
# 451       Punjab  ...                  NaN       16.0       19.0        23.0
# 452       Punjab  ...                  NaN        4.0        4.0         NaN
# 453          KPK  ...                  NaN        3.0        6.0        50.0
# 454        Sindh  ...                  NaN        1.0        NaN         2.0
# 455       Punjab  ...                  NaN        7.0        NaN        10.0
# 456  Balochistan  ...               Shiite       10.0       11.0        12.0
# 457        Sindh  ...               Shiite       22.0       23.0        40.0
# 458          KPK  ...                  NaN       21.0       26.0        50.0
# 459  Balochistan  ...                 None       15.0       15.0        25.0
# 460          KPK  ...                 None       10.0       12.0        20.0
# 461  Balochistan  ...                 None        0.0        0.0         5.0
# 462  Balochistan  ...                 None        9.0       11.0        30.0
# 463          KPK  ...                 None       10.0       20.0        27.0
# 464       Punjab  ...            Christian       70.0       72.0       233.0
#
#                                            Injured Max No. of Suicide Blasts  \
# 8                                                   35                   1.0
# 144                                                 16                   NaN
# 311                                                140                   2.0
# 312                                                  9                   1.0
# 313                                                 48                   1.0
# 314                                                 60                   1.0
# 315                                                 11                   1.0
# 316                                                 45                   1.0
# 317                                                107                   1.0
# 318                                                  6                   1.0
# 319                                                  5                   1.0
# 320                                                 26                   1.0
# 321                                                  2                   1.0
# 322                                                  7                   1.0
# 323                                                  0                   1.0
# 324                                                 12                   1.0
# 325                                                130                   1.0
# 328                                                 82                   2.0
# 329                                                 75                   1.0
# 330                                                  7                   1.0
# 331                                                NaN                   1.0
# 332                                                  9                   NaN
# 333                                                  1                   1.0
# 334                                                NaN                   1.0
# 335                                                 19                   1.0
# 336                                                NaN                   1.0
# 337                                                 28                   1.0
# 338                                                  9                   1.0
# 339                                                 10                   3.0
# 340                                                  8                   1.0
# 341                                                 36                   1.0
# 342                                                  3                   1.0
# 343                                                  6                   3.0
# 344                                                  6                   1.0
# 345                                                  3                   1.0
# 346                                                 33                   1.0
# 347                                                  5                   1.0
# 348                                                 10                   1.0
# 349                                                 14                   1.0
# 350                                                 75                   1.0
# 351                                                  5                   1.0
# 352                                                 30                   1.0
# 353                                                  8                   1.0
# 354                                                 21                   1.0
# 355                                                 80                   1.0
# 356                                                 41                   1.0
# 357                                                 10                   1.0
# 358                                                 37                   1.0
# 359                                                 23                   1.0
# 360                                                  4                   1.0
# 361                                                  7                   1.0
# 362                                                 40                   1.0
# 363                                                 80                   1.0
# 364                                                 18                   1.0
# 365                                                 10                   1.0
# 366                                                 25                   1.0
# 367                                                 20                   1.0
# 368                                                121                   2.0
# 369                                                 50                   1.0
# 370                                                 23                   1.0
# 371                                                NaN                   4.0
# 372                                                200                   1.0
# 373                                                NaN                   2.0
# 374                                                 47                   2.0
# 375                                                 35                   1.0
# 376                                                 35                   NaN
# 377                                                 60                   1.0
# 378                                                 18                   1.0
# 379                                                  4                   1.0
# 380                                                 40                   1.0
# 381                                                 45                   NaN
# 382                                                  2                   NaN
# 383                                                 40                   NaN
# 384                                                 27                   NaN
# 385                                                  5                   NaN
# 386                                                 68                   NaN
# 387                                                  2                   NaN
# 388                                                  2                   NaN
# 389                                                 19                   NaN
# 390                                                NaN                   NaN
# 391                                                 60                   NaN
# 392                                                 30                   NaN
# 393                                                 70                   NaN
# 394                                                 10                   NaN
# 395                                                 30                   2.0
# 396                                                200                   2.0
# 397                                                 60                   1.0
# 398                                                145                   2.0
# 399                                                 16                   1.0
# 400                                                 22                   1.0
# 401                                                  2                   NaN
# 402                                                 30                   NaN
# 403                                                  7                   NaN
# 404                                                  1                   NaN
# 405                                                 26                   NaN
# 406                                                NaN                   NaN
# 407                                                 34                   NaN
# 408                                                 21                   NaN
# 409                                                 31                   NaN
# 410                                                  2                   NaN
# 411                                                 11                   NaN
# 412                                                 15                   NaN
# 413                                                  8                   NaN
# 414                                                  1                   NaN
# 415                                                 50                   NaN
# 416                                                  5                   NaN
# 417                                                  3                   NaN
# 418                                                 47                   NaN
# 419                                                 10                   NaN
# 420                                                 29                   NaN
# 421                                                 45                   NaN
# 422                                                 15                   NaN
# 423                                                 11                   NaN
# 424                                                  5                   NaN
# 425                                                 16                   NaN
# 426                                                 24                   NaN
# 427                                                  5                   NaN
# 428                                                  1                   NaN
# 429                                                 29                   NaN
# 430                                                 12                   NaN
# 431                                                  5                   NaN
# 432                                                 20                   NaN
# 433                                                120                   NaN
# 434                                                132                   NaN
# 435                                                  0                   NaN
# 436                                                 39                   NaN
# 437                                                 60                   NaN
# 438                                                NaN                   NaN
# 439                                                  6                   NaN
# 440                                                 72                   NaN
# 441                                                  0                   NaN
# 442                                                  3                   NaN
# 443                                                NaN                   NaN
# 444                                                NaN                   NaN
# 445                                                  6                   NaN
# 446                                                  6                   NaN
# 447                                                NaN                   NaN
# 448                                                  7                   NaN
# 449  http://www.samaa.tv/pakistan/29-Jun-2015/shoot...                   NaN
# 450                                                NaN                   NaN
# 451                                                 25                   NaN
# 452                                                  2                   NaN
# 453                                                 56                   NaN
# 454                                                NaN                   1.0
# 455                                                 20                   1.0
# 456                                                 15                   1.0
# 457                                                40+                   NaN
# 458                                                 56                   NaN
# 459                                                 36                   NaN
# ...
# 341                    NaN                        Agency Headquarter Hospital
# 342                    NaN                                                NaN
# 343                    NaN                                                NaN
# 344                    6kg                        Lady Reading Hospital (LRH)
# 345                    NaN                     District Headquarters Hospital
# 346                    6Kg                        Lady Reading Hospital (LRH)
# 347                    6kg  Hayatabad Medical Hospital-Khyber Teaching Hos...
# 348                    NaN                                                NaN
# 349                    NaN                                                NaN
# 350                    NaN  Agency Headquarters Hospital (AHH)-Lady Readin...
# 351                    8Kg                        Lady Reading Hospital (LRH)
# 352                   50kg           Civil hospital-Bolan Medical Complex-CMH
# 353                    NaN                            District Hospital Bannu
# 354              100-110kg             Khyber Teaching Hospital-American Club
# 355                    NaN                                                NaN
# 356                   30kg                              Lady Reading Hospital
# 357                    NaN                    District Headquarters Hospital
# 358                7kg-8kg                              Lady Reading Hospital
# 359            100kg-150kg  Abbasi Shaheed Hospital-Sindh Rangers Hospital...
# 360                    NaN                     Ghallanai Headquarter Hospital
# 361                4kg-5kg             Qatar Hospital-Abbasi Shaheed Hospital
# 362                    NaN      DHQ-Combined Military-Benazir Bhutto Hospital
# 363                   12kg  District Headquarter Teaching Hospital-Combine...
# 364                    NaN                   Tehsil Headquarter Hospital Wana
# 365            600kg-800kg                                 DHQ Hospital Bannu
# 366                    NaN                           First Treatment Hospital
# 367                4kg-6kg                              Lady Reading Hospital
# 368                    NaN  Civil Hospital and the Combined Military Hospi...
# 369                    NaN                                          DHQ-Kohat
# 370                    NaN                                                NaN
# 371                    NaN                                                NaN
# 372                 1000kg  Civil Hospital and the Combined Military Hospital
# 373                    6kg                              Lady Reading Hospital
# 374                    6kg                              Lady Reading Hospital
# 375                    NaN                                                NaN
# 376                    NaN                              Lady Reading Hospital
# 377                    6kg                              Lady Reading Hospital
# 378                    NaN                        Military Hospital Miranshah
# 420          10.810          51.458
# 421          17.680          63.824
# 422          30.560          87.008
# 423          25.310          77.558
# 424          31.055          87.899
# 425          27.510          81.518
# 426          32.695          90.851
# 427          32.965          91.337
# 428          28.265          82.877
# 429          29.840          85.712
# 430          26.590          79.862
# 431          17.210          62.978
# 432          21.405          70.529
# 433          22.180          71.924
# 434           9.860          49.748
# 435           8.445          47.201
# 436          16.225          61.205
# 437          17.235          63.023
# 438          18.680          65.624
# 439          15.250          59.450
# 440          18.630          65.534
# 441          27.000          80.600
# 442          25.985          78.773
# 443          33.050          91.490
# 444          33.050          91.490
# 445          34.080          93.344
# 446          29.900          85.820
# 447          26.820          80.276
# 448          30.580          87.044
# 449             NaN             NaN
# 450             NaN             NaN
# 451          28.655          83.579
# 452          33.575          92.435
# 453          28.225          82.805
# 454          35.000          95.000
# 455          29.110          84.398
# 456          16.250          61.250
# 457          28.590          83.462
# 458          13.530          56.354
# 459           6.855          44.339
# 460          11.645          52.961
# 461          11.125          52.025
# 462           9.945          49.901
# 463          16.715          62.087
# 464          22.565          72.617
#
# [154 rows x 26 columns]

# %% [markdown]
# Write a note on the reason you think we have missing data on the three top columns : Islamic date, Holiday type and Time. remember  to classify them according to the three categories we analysed in the pdf.

# %% [markdown]
# For the following example, decide whether scaling or normalisation makes more sense.
#
# * You want to build a linear regression model to predict someone's grades given how much time they spend on various activities during a normal school week.  You notice that your measurements for how much time students spend studying aren't normally distributed: some students spend almost no time studying and others study for four or more hours every day. Should you scale or normalise this variable?
#
#
# We should normalise in this case variables as they are not normally distributed and standardisation requires that the underlying data is somewhat normally distributed.
# * You're still working on your grades study, but you want to include information on how students perform on several fitness tests as well. You have information on how many jumping jacks and push-ups each student can complete in a minute. However, you notice that students perform far more jumping jacks than push-ups: the average for the former is 40, and for the latter only 10. Should you scale or normalise these variables?
#
#
# Since the variables have different scales, it is best to compare them by normalising them (e.g. using minmax_scaling).

# %%
countries
# Out:
#    Country                                     Country Groups  \
# 0      CEB                     Central Europe and the Baltics
# 1      CSS                             Caribbean small states
# 2      EAP        East Asia & Pacific (excluding high income)
# 3      EAR                         Early-demographic dividend
# 4      EAS                                East Asia & Pacific
# 5      ECA      Europe & Central Asia (excluding high income)
# 6      ECS                              Europe & Central Asia
# 7      EMU                                          Euro area
# 8      EUU                                     European Union
# 9      FCS           Fragile and conflict affected situations
# 10     FSM                              Micronesia, Fed. Sts.
# 11     HIC                                        High income
# 12     HPC             Heavily indebted poor countries (HIPC)
# 13     IBD                                          IBRD only
# 14     IBT                                   IDA & IBRD total
# 15     IDA                                          IDA total
# 16     IDB                                          IDA blend
# 17     IDX                                           IDA only
# 18     LAC  Latin America & Caribbean (excluding high income)
# 19     LCN                          Latin America & Caribbean
# 20     LDC       Least developed countries: UN classification
# 21     LIC                                         Low income
# 22     LMC                                Lower middle income
# 23     LMY                                Low & middle income
# 24     LTE                          Late-demographic dividend
# 25     MEA                         Middle East & North Africa
# 26     MIC                                      Middle income
# 27     MNA  Middle East & North Africa (excluding high inc...
# 28     OED                                       OECD members
# 29     OSS                                 Other small states
# 30     PRE                           Pre-demographic dividend
# 31     PSS                        Pacific island small states
# 32     PST                          Post-demographic dividend
# 33     SSA         Sub-Saharan Africa (excluding high income)
# 34     SSF                                 Sub-Saharan Africa
# 35     SST                                       Small states
# 36     TEA         East Asia & Pacific (IDA & IBRD countries)
# 37     TEC       Europe & Central Asia (IDA & IBRD countries)
# 38     TLA  Latin America & the Caribbean (IDA & IBRD coun...
# 39     TMN  Middle East & North Africa (IDA & IBRD countries)
# 40     TSA                            South Asia (IDA & IBRD)
# 41     TSS          Sub-Saharan Africa (IDA & IBRD countries)
# 42     UMC                                Upper middle income
# 43     WLD                                              World
#
#     BX.KLT.DINV.WD.GD.ZS  EG.ELC.ACCS.ZS  EG.FEC.RNEW.ZS  EN.ATM.CO2E.PC  \
# 0               1.555790      100.000000       14.538355        6.820042
# 1               4.658176       93.114511        9.096342        9.277109
# 2               3.796483       94.997330       16.471817        5.106045
# 3               2.073571       79.455104       26.481427        2.119827
# 4               2.930966       95.496185       13.729447        5.701783
# 5               2.841455       99.498477        6.287939        7.520215
# 6               3.311091       99.772389       10.833148        7.540721
# 7               4.020539      100.000000       12.833088        7.425634
# 8               3.402097      100.000000       12.960029        7.354521
# 9               3.435664       40.804078       51.769428        0.833551
# 10              0.269791       64.531520        1.500334        1.097099
# 11              2.599367       99.984213        9.526558       11.562960
# 12              4.656115       27.908502       80.198571        0.221203
# 13              3.108258       91.457785       17.872047        4.121492
# 14              3.091863       80.705261       23.357177        3.271113
# 15              2.853402       46.025787       66.824234        0.523641
# 16              2.049943       64.387035       61.903298        0.907668
# 17              3.706545       36.991816       71.632632        0.332242
# 18              3.032455       95.749897       28.621615        2.761717
# 19              3.261416       95.910944       28.331401        2.905129
# 20              2.507053       32.514074       76.669035        0.269364
# 21              4.308013       23.086772       81.007145        0.264876
# 22              2.093759       75.419260       40.399181        1.345907
# 23              3.023092       80.336299       23.497013        3.224270
# 24              4.183336       98.385804       14.633152        6.076496
# 25              3.178368       95.982150        1.922598        5.847629
# 26              3.006615       86.474207       21.203821        3.540673
# 27              1.848351       95.350052        2.759434        3.818796
# 28              2.202096       99.919559       10.241596       10.172343
# 29             11.555964       64.480864       30.746787        6.564310
# 30              2.395405       32.009327       76.332188        0.466651
# 31              9.068878       68.566481       31.483044        1.096409
# 32              2.435132       99.996270        9.858593       11.088100
# 33              2.294643       32.626976       71.443341        0.850299
# 34              2.304839       32.633561       71.422468        0.850715
# 35             10.425761       70.374693       27.003716        6.760790
# 36              3.796429       95.839352       16.492741        5.136588
# 37              2.972856       99.541691        6.562926        7.587861
# 38              3.237232       95.801052       28.731619        2.864984
# 39              1.847225       95.297786        2.718620        3.856529
# 40              1.545553       75.117519       41.588760        1.207519
# 41              2.304839       32.633561       71.422468        0.850715
# 42              3.273893       98.843776       13.495764        5.996112
# 43              2.732319       83.539119       17.255192        4.828062
#
#     FP.CPI.TOTL.ZG  IT.CEL.SETS.P2  IT.NET.USER.ZS  NE.EXP.GNFS.ZS  ...  \
# 0         1.840965      122.192106       58.599297       52.333390  ...
# 1         3.250344      113.628492       35.407690       44.935642  ...
# 2         3.789836       69.905604       28.957482       30.572597  ...
# 3         4.580200       68.069446       12.835425       27.711023  ...
# 4         3.247588       73.657018       34.269800       32.153225  ...
# 5         6.281059      122.828868       35.800430       30.531140  ...
# 6         2.390258      120.365587       56.094025       37.982026  ...
# 7         1.529639      117.103652       70.966005       38.772603  ...
# 8         1.669887      118.568323       70.713150       38.325606  ...
# 9         3.624989       38.270423        5.971161       35.562683  ...
# 10             NaN       26.557674       20.000000       23.513744  ...
# 11        1.961885      109.042068       72.285537       29.454649  ...
# 12        4.700550       36.884260        4.723077       29.323019  ...
# 13        4.336842       78.855715       24.815064       27.988942  ...
# 14        4.406841       70.595568       20.545767       27.723529  ...
# 15        4.548982       43.824852        6.465312       23.519416  ...
# 16        3.436509       57.513685        9.572493       22.789028  ...
# 17        5.048937       37.080514        4.893792       24.175957  ...
# 18        3.859509       95.249241       34.202458       19.933027  ...
# 19        3.556124       96.147712       34.711889       21.699066  ...
# 20        5.982348       32.987287        4.128909       26.843154  ...
# 21        3.665655       28.254610        3.246713       24.611963  ...
# 22        5.997979       66.902830       10.936176       27.134347  ...
# 23        4.462753       69.645706       20.089811       27.260377  ...
# 24        3.288060       82.966233       36.033683       32.148960  ...
# 25        3.913043       91.181964       24.872679       45.226016  ...
# 26        4.580200       74.063530       21.817085       27.291790  ...
# 27        3.989841       80.332857       20.733304       31.888345  ...
# 28        1.813535      101.576549       67.640530       26.118637  ...
# 29        3.165169       86.723586       24.191917       62.168492  ...
# 30        3.976553       44.186577        6.099754       32.936014  ...
# 31             NaN       54.961185       12.974697       46.410710  ...
# 32        2.188538      105.105883       70.979559       27.495477  ...
# 33        4.257416       44.195995        6.988945       31.792453  ...
# 34        4.116984       44.204790        6.992579       31.844806  ...
# 35        3.228894       90.117398       25.724574       59.076911  ...
# 36        3.789836       70.759095       29.320133       30.572327  ...
# 37        6.142554      122.801761       38.103586       31.859184  ...
# 38        3.707816       97.906546       34.984453       20.811776  ...
# 39        4.193628       80.532820       20.529004       32.007673  ...
# 40        7.581530       58.680104        7.205784       21.130725  ...
# 41        4.116984       44.204790        6.992579       31.844806  ...
# 42        3.618069       82.006193       33.878396       27.336763  ...
# 43        3.491289       76.147222       28.733604       28.806724  ...
#
#     NY.GDP.PCAP.CD  SP.DYN.AMRT.FE  SP.DYN.AMRT.MA  SP.DYN.CBRT.IN  \
# 0     12567.128310       77.039930      189.578062       10.543330
# 1      8726.326154      121.928584      200.568068       17.555646
# 2      4007.323783       91.717833      134.835195       14.439063
# 3      2926.483907      150.595639      214.978616       22.914627
# 4      7674.475705       86.702958      130.465277       13.880915
# 5      7822.762509      113.337110      272.198910       14.984144
# 6     23536.968800       81.835521      183.332690       12.696487
# 7     37617.722310       50.157592      101.464956       10.357849
# 23        7.796518       40.700000       68.868002        2.652012
# 24        7.446510       14.225871       74.443007        1.685595
# 25        5.165597       23.181759       72.271770        2.877878
# 26        7.566424       36.000000       69.891620        2.412816
# 27        5.458020       24.700000       71.754805        2.896798
# 28        8.050552        7.132978       79.360966        1.789041
# 29        8.599084       46.936011       64.949191        3.298442
# 30       10.984616       67.125730       56.941264        5.608679
# 31        6.034642       23.223902       69.514353        3.428560
# 32        8.945127        4.762276       79.689129        1.661451
# 33       11.048779       65.200000       56.942283        5.249069
# 34       11.048405       65.185421       56.943945        5.248709
# 35        8.215641       41.305675       66.646909        3.066843
# 36        6.997145       19.089889       73.531874        1.842210
# 37       10.997735       16.310017       71.302699        1.811748
# 38        5.753647       18.960090       74.100076        2.205032
# 39        5.479352       24.786772       71.746888        2.881390
# 40        7.360384       49.007568       66.826757        2.744213
# 41       11.048405       65.185421       56.943945        5.248709
# 42        7.304136       15.900000       73.947336        1.816209
# 43        7.876908       37.400000       70.682937        2.508023
#
#     SP.POP.GROW  SP.URB.TOTL.IN.ZS
# 0     -0.362710          62.059417
# 1      0.642147          42.083135
# 2      0.713160          47.696831
# 3      1.534541          42.113134
# 4      0.675231          51.791229
# 5      0.497604          64.281869
# 6      0.386693          70.007745
# 7      0.235742          74.817182
# 8      0.219178          73.714758
# 9      2.449772          39.049597
# 10    -0.331445          22.298000
# 11     0.659096          80.024788
# 12     2.839076          32.362504
# 13     1.005011          49.916589
# 14     1.319963          45.991555
# 15     2.349280          33.315989
# 16     2.435229          38.494351
# 17     2.307044          30.763245
# 18     1.235334          78.119285
# 19     1.209072          78.425229
# 20     2.393216          28.977711
# 21     2.772463          28.701622
# 22     1.572886          36.958353
# 23     1.327722          45.888172
# 24     0.603694          55.197468
# 25     2.152467          62.386510
# 26     1.175235          47.731405
# 27     1.849113          58.808733
# 28     0.663447          78.999914
# 29     2.543913          55.962369
# 30     2.942033          35.993544
# 31     1.335335          36.567986
# 32     0.470363          79.734431
# 33     2.772359          35.249148
# 34     2.772365          35.250894
# 35     2.088010          52.018369
# 36     0.715590          47.537577
# 37     0.429670          63.988603
# 38     1.242578          78.379749
# 39     1.836704          58.632666
# 40     1.439535          30.982708
# 41     2.772365          35.250894
# 42     0.733982          59.777524
# 43     1.216246          51.454179
#
# [44 rows x 21 columns]

# %%
countries['EG.ELC.ACCS.ZS'].apply(lambda x : type(x)).unique()
# Out:
# array([<class 'float'>], dtype=object)

# %%
# From the countries dataset scale the "EG.ELC.ACCS.ZS" column and visualise it as well
scaled_data = minmax_scaling(countries['EG.ELC.ACCS.ZS'], columns = [0])

#plot both together to compare
fig, ax=plt.subplots(1,2)
sns.distplot(countries['EG.ELC.ACCS.ZS'], ax=ax[0])
ax[0].set_title("Original Data")
sns.distplot(scaled_data, ax=ax[1])
ax[1].set_title("Scaled data")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Scaled data')

# %%
# From the countries dataset standardise the "SP.DYN.CBRT.IN" column

# standardise the data (w/ Box-Cox)
data = countries['SP.DYN.CBRT.IN']
normalised_data = stats.boxcox(data)[0]

# plot both together to compare
fig, ax=plt.subplots(1,2)
sns.distplot(data, ax=ax[0])
ax[0].set_title("Original Data")
sns.distplot(normalised_data, ax=ax[1])
ax[1].set_title("Normalised data")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Normalised data')
